# %% [markdown]
# è sempre una buona idea splittare i dati in training e test, altrimenti non si può garantire la solidità del modello (anche se non ancora spiegati c'è dietro il concetto di overfitting e underfitting)
#
# il ciclo di machine learning è
#
# definisco iperparametri
# addestro il modello
# testo il modello
# se risultati soddisfacenti vado alla fine, altrimenti definisco nuovi iperparametri
#
# i dati di test devono essere nuovi e mai visti, così nasce la necessità di splittare i dati in 2 dataset randomici
#
# i dati di addestramento devono essere considerevolmente maggiori a quelli di test
# fino a 10k dati si parla di 70/30
# oltre un milione si può anche parare di 98/2
#
# questa volta non posso usare il dataset dell'ecommerce perchè il dataset è pensato piu per l'analisi che per l'addestramento di modelli di ml
# userò il dataset di iris

# %%
from sklearn.datasets import load_diabetes

# %%
diabets = load_diabetes()

diabets.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
diabets.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
diabets.DESCR
# Out:
# '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n:Number of Instances: 442\n\n:Number of Attributes: First 10 columns are numeric predictive values\n\n:Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n:Attribute Information:\n    - age     age in years\n    - sex\n    - bmi     body mass index\n    - bp      average blood pressure\n    - s1      tc, total serum cholesterol\n    - s2      ldl, low-density lipoproteins\n    - s3      hdl, high-density lipoproteins\n    - s4      tch, total cholesterol / HDL\n    - s5      ltg, possibly log of serum triglycerides level\n    - s6      glu, blood sugar level\n\nNote: Each of th
# ...

# %%
diabets.data.shape
# Out:
# (442, 10)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(diabets.data, diabets.target, test_size=.3)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (309, 10)
# (133, 10)
# (309,)
# (133,)

# %%
import pandas as pd
import numpy as np

# %%
diabets.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
#converto un array numpy in un dataframe pandas
diabets_df = pd.DataFrame(data=np.c_[diabets.data, diabets.target], columns=np.append(diabets.feature_names, 'TARGET'))

diabets_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  TARGET
# ...

# %% [markdown]
# eseguo lo splitting del dataframe pandas

# %%
test_df = diabets_df.sample(frac=0.3)
test_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 198 -0.052738 -0.044642  0.054152 -0.026328 -0.055231 -0.033881 -0.013948
# 144  0.030811  0.050680  0.046607 -0.015999  0.020446  0.050669 -0.058127
# 283 -0.016412 -0.044642 -0.052552 -0.033213 -0.044223 -0.036387  0.019187
# 83  -0.038207 -0.044642  0.009961 -0.046985 -0.059359 -0.052983 -0.010266
# 74   0.012648  0.050680  0.002417  0.056301  0.027326  0.017162  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 301 -0.001882  0.050680 -0.024529  0.052858  0.027326  0.030001  0.030232
# 89  -0.045472 -0.044642 -0.048241 -0.019442 -0.000193 -0.016032  0.067048
# 78   0.005383 -0.044642 -0.057941 -0.022885 -0.067615 -0.068328 -0.054446
# 392 -0.041840  0.050680 -0.029918 -0.002228  0.021822  0.036577  0.011824
# 377  0.019913  0.050680  0.009961  0.018430  0.014942  0.044719 -0.061809
#
#            s4        s5        s6  TARGET
# ...

# %%
train_df = diabets_df.drop(test_df.index)
train_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 432  0.009016 -0.044642  0.055229 -0.005670  0.057597  0.044719 -0.002903
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 436 -0.056370 -0.044642 -0.074108 -0.050427 -0.024960 -0.047034  0.092820
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
#
#            s4        s5        s6  TARGET
# ...

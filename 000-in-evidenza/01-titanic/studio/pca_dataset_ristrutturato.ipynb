# %%
import scripts.csv_continue_to_ds_discreet as csvContinue2DSDiscreet
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

# %%
X, y = csvContinue2DSDiscreet.csvContinue2DSDiscreet()

# %%
X.columns
# Out:
# Index(['age_is_null', 'isChild', 'isTeen', 'isAdult', 'isSenior', 'isOld',
#        'IsAlone', 'IsSmallFamily', 'IsBigFamily', 'FirstClass', 'SecondClass',
#        'ThirdClass', 'EmbarkedS', 'EmbarkedC', 'EmbarkedQ', 'Male'],
#       dtype='object')

# %% [markdown]
# effettuo la principal component analysis

# %%
pca = PCA(random_state=0, n_components=None)
X_train_pca = pca.fit(X)
variance_ratio = X_train_pca.explained_variance_ratio_

variance_ratio_cumulative = np.cumsum(variance_ratio)

# %%
plt.figure(figsize=(20, 12))
plt.step(range(1, len(variance_ratio_cumulative) + 1), variance_ratio_cumulative, where='mid', label='Cumulative Explained Variance')
plt.bar(range(1, len(variance_ratio) + 1), variance_ratio, label='Explained Variance by Component')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Component')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Threshold')
plt.show()

# %%
from scripts.csv_continue_to_ds_discreet import csv_continue_to_ds_discreet
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = csv_continue_to_ds_discreet()

# %%
df = pd.concat([X, pd.Series(y)], axis=1)

df
# Out:
#       hypertension  heart_disease  ever_married  age_low_risk  \
# 0                0              1          True         False
# 1                0              1          True         False
# 2                0              0          True         False
# 3                1              0          True         False
# 4                0              0          True         False
# ...            ...            ...           ...           ...
# 4848             0              0         False          True
# 4849             0              0          True         False
# 4850             0              0          True          True
# 4851             0              0          True         False
# 4852             0              0          True         False
#
#       age_medium_risk  age_high_risk  glucose_low_risk  glucose_medium_risk  \
# 0               False           True             False                False
# 1               False           True              True                False
# 2                True          False             False                 True
# 3               False           True             False                 True
# 4               False           True             False                 True
# ...               ...            ...               ...                  ...
# 4848            False          False              True                False
# 4849            False           True             False                 True
# 4850            False          False              True                False
# 4851             True          False             False                 True
# 4852             True          False              True                False
#
#       glucose_high_risk  bmi_low_risk  ...  work_governative  work_private  \
# 0                  True         False  ...             False          True
# 1                 False         False  ...             False          True
# 2                 False         False  ...             False          True
# 3                 False          True  ...             False         False
# 4                 False         False  ...             False          True
# ...                 ...           ...  ...               ...           ...
# 4848              False          True  ...             False         False
# 4849              False         False  ...             False         False
# 4850              False         False  ...             False         False
# 4851              False         False  ...             False          True
# 4852              False         False  ...              True         False
#
#       work_self  work_never  Residence_type_Urban  smoking_status_former  \
# 0         False       False                  True                   True
# 1         False       False                 False                  False
# 2         False       False                  True                  False
# 3          True       False                 False                  False
# 4         False       False                  True                   True
# ...         ...         ...                   ...                    ...
# 4848      False        True                 False                  False
# 4849       True       False                  True                  False
# 4850       True       False                 False                  False
# 4851      False       False                 False                   True
# 4852      False       False                  True                  False
#
#       smoking_status_never  smoking_status_smokes  smoking_status_unknown  0
# 0                    False                  False                   False  1
# 1                     True                  False                   False  1
# 2                    False                   True                   False  1
# 3                     True                  False                   False  1
# 4                    False                  False                   False  1
# ...                    ...                    ...                     ... ..
# 4848                 False                  False                    True  0
# 4849                  True                  False                   False  0
# 4850                  True                  False                   False  0
# 4851                 False                  False                   False  0
# 4852                 False                  False                    True  0
#
# [4853 rows x 23 columns]

# %%
# df = df[~df['hypertension'].isnull()]

df
# Out:
#       hypertension  heart_disease  ever_married  age_low_risk  \
# 0                0              1          True         False
# 1                0              1          True         False
# 2                0              0          True         False
# 3                1              0          True         False
# 4                0              0          True         False
# ...            ...            ...           ...           ...
# 4848             0              0         False          True
# 4849             0              0          True         False
# 4850             0              0          True          True
# 4851             0              0          True         False
# 4852             0              0          True         False
#
#       age_medium_risk  age_high_risk  glucose_low_risk  glucose_medium_risk  \
# 0               False           True             False                False
# 1               False           True              True                False
# 2                True          False             False                 True
# 3               False           True             False                 True
# 4               False           True             False                 True
# ...               ...            ...               ...                  ...
# 4848            False          False              True                False
# 4849            False           True             False                 True
# 4850            False          False              True                False
# 4851             True          False             False                 True
# 4852             True          False              True                False
#
#       glucose_high_risk  bmi_low_risk  ...  work_governative  work_private  \
# 0                  True         False  ...             False          True
# 1                 False         False  ...             False          True
# 2                 False         False  ...             False          True
# 3                 False          True  ...             False         False
# 4                 False         False  ...             False          True
# ...                 ...           ...  ...               ...           ...
# 4848              False          True  ...             False         False
# 4849              False         False  ...             False         False
# 4850              False         False  ...             False         False
# 4851              False         False  ...             False          True
# 4852              False         False  ...              True         False
#
#       work_self  work_never  Residence_type_Urban  smoking_status_former  \
# 0         False       False                  True                   True
# 1         False       False                 False                  False
# 2         False       False                  True                  False
# 3          True       False                 False                  False
# 4         False       False                  True                   True
# ...         ...         ...                   ...                    ...
# 4848      False        True                 False                  False
# 4849       True       False                  True                  False
# 4850       True       False                 False                  False
# 4851      False       False                 False                   True
# 4852      False       False                  True                  False
#
#       smoking_status_never  smoking_status_smokes  smoking_status_unknown  0
# 0                    False                  False                   False  1
# 1                     True                  False                   False  1
# 2                    False                   True                   False  1
# 3                     True                  False                   False  1
# 4                    False                  False                   False  1
# ...                    ...                    ...                     ... ..
# 4848                 False                  False                    True  0
# 4849                  True                  False                   False  0
# 4850                  True                  False                   False  0
# 4851                 False                  False                   False  0
# 4852                 False                  False                    True  0
#
# [4853 rows x 23 columns]

# %%
plt.figure(figsize=(24, 20))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <Axes: >
